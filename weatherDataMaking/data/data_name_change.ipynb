# %%
import pandas as pd
import numpy as np

df = pd.read_csv('part_by.csv')

# %%
df
# Out:
#            채승       건형       서하       수현
# 0     1110936   243062  1015438   406731
# 1     1039407   583982   435318   976409
# 2     1348211   595864  1308113   590650
# 3     1129167   817524   500015   570980
# 4      468945   454492   547295   833786
# ...       ...      ...      ...      ...
# 2917   107516   938519  1344259  1232934
# 2918   694524  1100084  1124086   552592
# 2919   742153  1039605   730534   783193
# 2920  1288998  1202446   819206   604503
# 2921  1202554  1181105   817540   823569
#
# [2922 rows x 4 columns]

# %%
df.columns = ['chaeseong', 'gunhyeong', 'seoha', 'suhyeon']

# %%
import numpy as np

df['weather_gt']= np.zeros(11691)

# %%
df = df.astype('Int64')

# %%
df= df.astype('Int64').astype('string')

# %%
df
# Out:
#       chaeseong  gunhyeong    seoha  suhyeon
# 0       1110936     243062  1015438   406731
# 1       1039407     583982   435318   976409
# 2       1348211     595864  1308113   590650
# 3       1129167     817524   500015   570980
# 4        468945     454492   547295   833786
# ...         ...        ...      ...      ...
# 2917     107516     938519  1344259  1232934
# 2918     694524    1100084  1124086   552592
# 2919     742153    1039605   730534   783193
# 2920    1288998    1202446   819206   604503
# 2921    1202554    1181105   817540   823569
#
# [2922 rows x 4 columns]

# %%
df
# Out:
#         젠더리스      스포티       기타      컨트리     밀리터리       섹시       히피 소피스트케이티드  \
# 0     190479  1267466  1348231   816558   702714   507085   794339  1103144
# 1     831061   563247  1348823   361373  1057115  1184863   794535   868779
# 2     801256   359111  1348284   163341   649176   245896   814725   706913
# 3       1037  1268256  1348777  1206643   811101   365015   130304   258106
# 4     918562   918182  1348761   614791   433941   998554   677882    65256
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 495  1243030   816313  1348456   777520   275426  1161441     8215   760102
# 496   742607  1006115  1348201   215425   433950   840859   165059   859578
# 497   597907   880923   684119  1217380   796933  1298709  1302431   687488
# 498  1182833   665453  1348805   355003   123928   531905   365365   506742
# 499  1039069   875763   616227   859471   796948  1077631   969215  1016234
#
# ...

# %%
for i in names:
    df[i] = df[i].str.replace('.json', '')


df
# Out:
# /var/folders/r1/fdc93wbn3d74p2p0q65jtw1m0000gn/T/ipykernel_25570/1200734490.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[i] = df[i].str.replace('.json', '')
#         젠더리스      스포티       기타      컨트리     밀리터리       섹시       히피 소피스트케이티드  \
# 0     190479  1267466  1348231   816558   702714   507085   794339  1103144
# 1     831061   563247  1348823   361373  1057115  1184863   794535   868779
# 2     801256   359111  1348284   163341   649176   245896   814725   706913
# 3       1037  1268256  1348777  1206643   811101   365015   130304   258106
# 4     918562   918182  1348761   614791   433941   998554   677882    65256
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 495  1243030   816313  1348456   777520   275426  1161441     8215   760102
# 496   742607  1006115  1348201   215425   433950   840859   165059   859578
# ...

# %%
df.to_csv('part_by.csv', index=False)
